# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import string
from string import digits
import re
from sklearn.utils import shuffle
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import LSTM, Input, Dense,Embedding, Concatenate, TimeDistributed
from tensorflow.keras.models import Model,load_model, model_from_json
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.text import one_hot, Tokenizer
from tensorflow.keras.callbacks import EarlyStopping
import pickle as pkl
import numpy as np

# %%
with open('.//pol-eng//pol.txt','r',encoding="utf8") as f:
  data = f.read()

# %%
data[:6]
# Out:
# 'Go.\tId'

# %% [markdown]
# # Data Preprocessing

# %%
uncleaned_data_list = data.split('\n')
len(uncleaned_data_list)
uncleaned_data_list[0]
# Out:
# 'Go.\tIdź.\tCC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #7818294 (Hanyel)'

# %%
uncleaned_data_list = uncleaned_data_list[:40000]
len(uncleaned_data_list)
# Out:
# 40000

# %%
english_word = []
pol_word = []
cleaned_data_list = []
for word in uncleaned_data_list:
  english_word.append(word.split('\t')[:-1][0])
  pol_word.append(word.split('\t')[:-1][1])

# %%
english_word
# Out:
# ['Go.',
#  'Hi.',
#  'Run!',
#  'Run.',
#  'Run.',
#  'Who?',
#  'Wow!',
#  'Wow!',
#  'Fire!',
#  'Fire!',
#  'Fire!',
#  'Help!',
#  'Jump!',
#  'Jump.',
#  'Stop!',
#  'Stop!',
#  'Wait!',
#  'Wait!',
#  'Wait!',
#  'Wait!',
#  'Wait!',
#  'Wait!',
#  'Wait!',
#  'Wait!',
#  'Wait.',
#  'Wait.',
#  'Wait.',
#  'Wait.',
#  'Wait.',
#  'Wait.',
#  'Begin.',
#  'Begin.',
#  'Do it.',
#  'Hello!',
#  'Hurry!',
#  'I see.',
#  'I see.',
#  'I try.',
#  'I won!',
#  'Oh no!',
#  'Relax.',
#  'Shoot!',
#  'Shoot!',
#  'Smile.',
#  'Attack!',
#  'Cheers!',
#  'Cheers!',
#  'Eat it.',
#  'Freeze!',
#  'Freeze!',
#  'Get up.',
#  'Go now.',
#  'Got it?',
#  'Got it?',
#  'He ran.',
#  'Hop in.',
#  'Hug me.',
#  'I fell.',
#  'I know.',
#  'I left.',
#  'I left.',
#  'I left.',
#  'I left.',
#  'I left.',
#  'I left.',
#  'I lost.',
#  'I quit.',
#  "I'm OK.",
#  'Listen.',
#  'No way!',
#  'Really?',
#  'Thanks.',
#  'Thanks.',
#  'We try.',
#  'Why me?',
#  'Ask Tom.',
#  'Ask Tom.',
#  'Awesome!',
#  'Be calm.',
#  'Be cool.',
#  'Be fair.',
#  'Be kind.',
#  'Be nice.',
#  'Beat it.',
#  'Call me.',
#  'Call us.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come in.',
#  'Come on!',
#  'Come on!',
#  'Come on.',
#  'Drop it!',
#  'Get Tom.',
#  'Get Tom.',
#  'Get out!',
#  'Get out.',
#  'Get out.',
#  'Go away!',
#  'Go away.',
#  'Go away.',
#  'Go home.',
#  'Goodbye!',
#  'Hang on.',
#  'He came.',
#  'He left.',
#  'He runs.',
#  'Help me!',
#  'Help me.',
#  'Hi, Tom.',
#  'Hit Tom.',
#  'Hold it!',
#  'Hold on.',
#  'Hold on.',
#  'Hold on.',
#  'Hug Tom.',
#  'I agree.',
#  'I bowed.',
#  'I smoke.',
#  'I stink.',
#  'I tried.',
#  "I'll go.",
#  "I'm Tom.",
#  "I'm old.",
#  "I'm sad.",
#  "I'm shy.",
#  "I'm shy.",
#  "It's me!",
#  "It's me!",
#  'Join us.',
#  'Join us.',
#  'Keep it.',
#  'Kiss me.',
#  'Me, too.',
#  'Me, too.',
#  'Open up.',
#  'Perfect!',
#  'Quit it!',
#  'See you!',
#  'See you!',
#  'Show me.',
#  'Shut up!',
#  'Stop it.',
#  'Take it.',
#  'Tell me.',
#  'Tom ate.',
#  'Tom ran.',
#  'Wait up.',
#  'Wait up.',
#  'Wake up!',
#  'Wake up.',
#  'We lost.',
#  'Welcome.',
#  'Welcome.',
#  'Who ate?',
#  'Who ran?',
#  'Who won?',
#  'You run.',
#  'You won.',
#  'Back off!',
#  'Back off.',
#  'Be quiet.',
#  'Be quiet.',
#  'Be quiet.',
#  'Be quiet.',
#  'Be still.',
#  'Buzz off.',
#  'Buzz off.',
#  'Buzz off.',
#  'Buzz off.',
#  'Call Tom.',
#  'Cheer up!',
#  'Cheer up.',
#  'Cheer up.',
#  'Cheer up.',
#  'Cheer up.',
#  'Cool off!',
#  'Cuff him.',
#  'Drive on.',
#  'Find Tom.',
#  'Fix this.',
#  'Get down!',
#  'Get down.',
#  'Get lost!',
#  'Get lost.',
#  'Get real!',
#  'Get real.',
#  'Get real.',
#  'Get real.',
#  'Go ahead!',
#  'Go ahead.',
#  'Go ahead.',
#  'Go ahead.',
#  'Good job!',
#  'Grab Tom.',
#  'Grab him.',
#  'Have fun.',
#  'He tried.',
#  'He tries.',
#  'He tries.',
#  'Help Tom.',
#  'How cute!',
#  'How deep?',
#  'How nice!',
#  'Hurry up.',
#  'I agreed.',
#  'I agreed.',
#  'I agreed.',
#  'I did it.',
#  'I failed.',
#  'I failed.',
#  'I failed.',
#  'I failed.',
#  'I failed.',
#  'I failed.',
#  'I failed.',
#  'I forgot.',
#  'I get it.',
#  'I got it.',
#  'I phoned.',
#  'I resign.',
#  'I resign.',
#  'I smiled.',
#  'I stayed.',
#  "I'll pay.",
#  "I'll try.",
#  "I'm busy.",
#  "I'm busy.",
#  "I'm cool.",
#  "I'm done.",
#  "I'm fair.",
#  "I'm free!",
#  "I'm full.",
#  "I'm glad.",
#  "I'm here.",
#  "I'm home.",
#  "I'm hurt.",
#  "I'm late.",
#  "I'm lost.",
#  "I'm lost.",
#  "I'm lost.",
#  "I'm mean.",
#  "I'm next.",
#  "I'm poor.",
#  "I'm rich.",
#  "I'm safe.",
#  "I'm sick.",
#  "I'm sure.",
#  "I'm warm.",
#  "I'm weak.",
#  "I'm wise.",
#  "I've won.",
#  'It works.',
#  "It's hot.",
#  "It's new.",
#  "It's red.",
#  "It's red.",
#  "It's red.",
#  'Keep out!',
#  'Keep out.',
#  'Kiss Tom.',
#  'Leave it.',
#  'Leave me.',
#  'Leave us.',
#  "Let's go!",
#  'Look out!',
#  'Marry me.',
#  'May I go?',
#  'Save Tom.',
#  'She came.',
#  'She runs.',
#  'Sit down!',
#  'Sit down!',
#  'Sit down.',
#  'Sit here.',
#  'Speak up!',
#  'Stand by.',
#  'Stand up!',
#  'Stay put.',
#  'Stop Tom.',
#  'Take Tom.',
#  'Tell Tom.',
#  'Terrific!',
#  'They won.',
#  'Tom came.',
#  'Tom died.',
#  'Tom fell.',
#  'Tom knew.',
#  'Tom left.',
#  'Tom lied.',
#  'Tom lies.',
#  'Tom lost.',
#  'Tom paid.',
#  'Tom quit.',
#  'Tom swam.',
#  'Touch it.',
#  'Trust me.',
#  'Try hard.',
#  'Try some.',
#  'Try this.',
#  'Use this.',
#  'Warn Tom.',
#  'Watch me.',
#  'Watch us.',
#  'We agree.',
#  'What for?',
#  'What fun!',
#  'Who died?',
#  'Who died?',
#  'Who fell?',
#  'Who quit?',
#  "Who's he?",
#  'Write me.',
#  'After you.',
#  'Aim. Fire!',
#  'Be seated.',
#  'Birds fly.',
#  'Calm down!',
#  'Calm down!',
#  'Calm down.',
#  'Can I eat?',
#  'Catch Tom.',
#  'Catch him.',
#  'Chill out.',
#  'Chill out.',
#  'Come back.',
#  'Come here.',
#  'Come home.',
#  'Come over!',
#  'Come over.',
#  'Come soon.',
#  'Cool down.',
#  'Did I win?',
#  'Do it now.',
#  'Dogs bark.',
#  "Don't cry.",
#  "Don't die.",
#  "Don't lie.",
#  'Excuse me?',
#  'Excuse me?',
#  'Excuse me?',
#  'Fantastic!',
#  'Feel this.',
#  'Follow me.',
#  'Follow us.',
#  'Forget it!',
#  'Forget it!',
#  'Forget it.',
#  'Forget it.',
#  'Forget it.',
#  'Forget it.',
#  'Get ready.',
#  'Go inside.',
#  'Grab that.',
#  'Grab that.',
#  'Grab this.',
#  'Hands off.',
#  'Have some.',
#  'Have some.',
#  'He is ill.',
#  'He is old.',
#  'He shaved.',
#  'He smiled.',
#  "He's a DJ.",
#  "He's busy.",
#  "He's rich.",
#  'Hold fire.',
#  'Hold this.',
#  'Humor Tom.',
#  'I am good.',
#  'I am sick.',
#  'I am sure.',
#  'I am sure.',
#  'I am tall.',
#  'I am well.',
#  'I clapped.',
#  'I cringed.',
#  'I cringed.',
#  'I fainted.',
#  'I fainted.',
#  'I get you.',
#  'I hit Tom.',
#  'I hurried.',
#  'I laughed.',
#  'I made it.',
#  'I must go.',
#  'I noticed.',
#  'I noticed.',
#  'I said no.',
#  'I see Tom.',
#  'I shouted.',
#  'I stopped.',
#  'I tripped.',
#  'I tripped.',
#  'I tripped.',
#  "I'd leave.",
#  "I'll call.",
#  "I'll cook.",
#  "I'll live.",
#  "I'll pass.",
#  "I'll sing.",
#  "I'll stay.",
#  "I'll stop.",
#  "I'll talk.",
#  "I'll wait.",
#  "I'll walk.",
#  "I'm a man.",
#  "I'm armed.",
#  "I'm blind.",
#  "I'm bored.",
#  "I'm bored.",
#  "I'm brave.",
#  "I'm broke.",
#  "I'm clean.",
#  "I'm cured.",
#  "I'm drunk.",
#  "I'm first.",
#  "I'm going.",
#  "I'm happy.",
#  "I'm happy.",
#  "I'm quiet.",
#  "I'm ready.",
#  "I'm right.",
#  "I'm smart.",
#  "I'm sober.",
#  "I'm sorry.",
#  "I'm stuck.",
#  "I'm tired.",
#  "I'm tough.",
#  "I'm young.",
#  "I'm yours.",
#  "I've lost.",
#  'Ignore it.',
#  'Is it hot?',
#  'Is it hot?',
#  'It failed.',
#  'It failed.',
#  'It snowed.',
#  'It stinks.',
#  'It stinks.',
#  'It worked.',
#  'It worked.',
#  "It's 3:30.",
#  "It's a TV.",
#  "It's easy.",
#  "It's hard.",
#  "It's late.",
#  "It's work.",
#  'Keep away.',
#  'Keep back.',
#  'Keep calm.',
#  'Keep cool.',
#  'Keep down.',
#  'Keep that.',
#  'Keep them.',
#  'Keep this.',
#  'Keep warm.',
#  'Leave Tom.',
#  'Leave now!',
#  'Leave now!',
#  'Leave now!',
#  'Leave now!',
#  'Let it be.',
#  "Let's ask.",
#  "Let's eat.",
#  "Let's try.",
#  'Lie still.',
#  'Listen up.',
#  'Listen up.',
#  'Listen up.',
#  'Listen up.',
#  'Listen up.',
#  'Look away.',
#  'Look back!',
#  'Look back.',
#  'Look here.',
#  'Loosen it.',
#  'Loosen up.',
#  'Move over.',
#  'Nice shot!',
#  'Of course!',
#  'Of course.',
#  'Oh please!',
#  'Open fire!',
#  'Open fire!',
#  'Pardon me?',
#  'Pipe down!',
#  'Pipe down!',
#  'Pipe down!',
#  'Pipe down!',
#  'Pipe down!',
#  'Pipe down!',
#  'Pipe down!',
#  'Pipe down!',
#  'Pipe down!',
#  'Please go.',
#  'Please go.',
#  'Please go.',
#  'Read this.',
#  'Read this.',
#  'Say "aah."',
#  'Say hello.',
#  'Say hello.',
#  'See below.',
#  'Seize him!',
#  'Seriously?',
#  'Seriously?',
#  'Seriously?',
#  'She cried.',
#  'She tried.',
#  'She walks.',
#  'Sign this.',
#  'Sit still.',
#  'Sit there.',
#  'Sit there.',
#  'Slow down!',
#  'Slow down!',
#  'Slow down!',
#  'Slow down!',
#  'Slow down!',
#  'Slow down!',
#  'Slow down!',
#  'Start now.',
#  'Stay away.',
#  'Stay back.',
#  'Stay calm.',
#  'Stay cool.',
#  'Stay down!',
#  'Stay down!',
#  'Stay down!',
#  'Stay down!',
#  'Stay down!',
#  'Stay down!',
#  'Stay down.',
#  'Stay here.',
#  'Stay home.',
#  'Step back.',
#  'Stop here.',
#  'Stop that.',
#  'Stop them.',
#  'Take care!',
#  'Take care.',
#  'Take over.',
#  'Take this.',
#  'Thank you.',
#  'Thank you.',
#  "That's it.",
#  'Then what?',
#  'They fell.',
#  'They left.',
#  'They lied.',
#  'They lost.',
#  'They swam.',
#  'Tom cared.',
#  'Tom cares.',
#  'Tom cried.',
#  'Tom dozed.',
#  'Tom drove.',
#  'Tom knits.',
#  'Tom knits.',
#  'Tom knows.',
#  'Tom moved.',
#  'Tom rocks.',
#  'Tom spoke.',
#  'Tom stood.',
#  'Tom swims.',
#  'Tom tried.',
#  'Tom tries.',
#  'Tom voted.',
#  'Tom walks.',
#  'Tom waved.',
#  'Tom works.',
#  "Tom's shy.",
#  'Trust Tom.',
#  'Try again.',
#  'Turn left.',
#  'Unlock it.',
#  'Wait here.',
#  'Watch Tom.',
#  'Watch out!',
#  'We did it.',
#  'We did it.',
#  'We forgot.',
#  'We forgot.',
#  'We talked.',
#  'We waited.',
#  "We'll see.",
#  "We're sad.",
#  'Well done!',
#  "What's up?",
#  "What's up?",
#  'Who cares?',
#  'Who knows?',
#  'Who knows?',
#  'Who spoke?',
#  'Who spoke?',
#  'Who spoke?',
#  'Who spoke?',
#  'Who stood?',
#  "Who's she?",
#  'Wonderful!',
#  'Wonderful!',
#  'Wonderful!',
#  'Wonderful!',
#  'Write Tom.',
#  'You idiot!',
#  'You start.',
#  'You tried.',
#  "You're OK.",
#  'All aboard!',
#  'Am I wrong?',
#  'Answer Tom.',
#  'Are you OK?',
#  'Are you OK?',
#  'Are you OK?',
#  'Ask anyone.',
#  'Ask anyone.',
#  'Ask around.',
#  'Be careful!',
#  'Be careful.',
#  'Be careful.',
#  'Be content.',
#  'Be content.',
#  'Be content.',
#  'Be on time.',
#  'Be patient.',
#  'Be patient.',
#  'Be patient.',
#  'Be serious.',
#  'Be serious.',
#  'Birds sing.',
#  'Bottoms up!',
#  'Bottoms up!',
#  'Bottoms up!',
#  'Carry this.',
#  'Check this.',
#  'Choose one.',
#  'Choose one.',
#  'Come along.',
#  'Definitely!',
#  'Destroy it.',
#  "Don't move.",
#  'Eat slowly.',
#  'Examine it.',
#  'Face facts!',
#  'Face facts!',
#  'Face facts!',
#  'Fill it up.',
#  'Fire burns.',
#  'Follow Tom.',
#  'Follow him.',
#  'Forget Tom.',
#  'Forget him.',
#  'Forgive me.',
#  'God exists.',
#  'Good night.',
#  'He gave in.',
#  'He is a DJ.',
#  'He is here!',
#  'He is nice.',
#  'He is poor.',
#  'He is sick.',
#  "He's smart.",
#  'Hold still.',
#  'Hold still.',
#  'Hold still.',
#  'Hold still.',
#  'Hold still.',
#  'Hold still.',
#  'Hold still.',
#  'How absurd!',
#  'How absurd!',
#  'How absurd!',
#  'How absurd!',
#  'How clever!',
#  'How clever!',
#  'How clever!',
#  'How clever!',
#  'How lovely!',
#  'How tragic!',
#  'Hurry back.',
#  'Hurry back.',
#  'Hurry back.',
#  'Hurry home.',
#  'I am a boy.',
#  'I am a man.',
#  'I am a man.',
#  'I am happy.',
#  'I am ready.',
#  'I am short.',
#  'I am short.',
#  'I am smart.',
#  'I beat Tom.',
#  'I canceled.',
#  'I disagree.',
#  'I doubt it.',
#  'I eat here.',
#  'I eat meat.',
#  'I guess so.',
#  'I hate Tom.',
#  'I hate you.',
#  'I hate you.',
#  'I know Tom.',
#  'I know her.',
#  'I know him.',
#  'I like art.',
#  'I like him.',
#  'I like tea.',
#  'I like you.',
#  'I listened.',
#  'I love him.',
#  'I love you.',
#  'I miss you.',
#  'I miss you.',
#  'I need air.',
#  'I need you.',
#  'I survived.',
#  'I think so.',
#  'I think so.',
#  'I want you.',
#  'I was sick.',
#  "I'll check.",
#  "I'll drive.",
#  "I'll leave.",
#  "I'll shoot.",
#  "I'll stand.",
#  "I'll start.",
#  "I'm 30 now.",
#  "I'm a hero.",
#  "I'm anemic.",
#  "I'm bushed.",
#  "I'm coming.",
#  "I'm direct.",
#  "I'm direct.",
#  "I'm eating.",
#  "I'm hungry!",
#  "I'm in bed.",
#  "I'm mature.",
#  "I'm paying.",
#  "I'm pooped.",
#  "I'm scared.",
#  "I'm strict.",
#  "I'm strong.",
#  'Ignore Tom.',
#  'Ignore him.',
#  'Ignore him.',
#  'Is it blue?',
#  'Is it love?',
#  'It is 7:30.',
#  'It is 7:30.',
#  'It is 7:30.',
#  'It is 7:30.',
#  'It is 7:45.',
#  'It is warm.',
#  'It matters.',
#  'It was sad.',
#  "It's early.",
#  "It's safer.",
#  "It's safer.",
#  "It's windy.",
#  'Jesus wept.',
#  'Keep going.',
#  'Keep notes.',
#  'Keep quiet!',
#  'Keep quiet.',
#  'Keep still.',
#  'Leave town.',
#  'Let me pay.',
#  "Let's chat.",
#  "Let's work.",
#  'Lighten up.',
#  'Look again.',
#  'Look ahead.',
#  'Look alert.',
#  'Look alive.',
#  'Look there.',
#  'Look there.',
#  'Love hurts.',
#  'Love lasts.',
#  'Mama cried.',
#  'Never mind!',
#  'Never mind!',
#  'Never mind!',
#  'Never mind!',
#  'Never mind!',
#  'Never mind!',
#  'No comment.',
#  'No problem!',
#  'No problem!',
#  'No problem!',
#  'No problem!',
#  'No problem.',
#  'No problem.',
#  'Once again.',
#  'Please sit.',
#  'Quiet down.',
#  'Quiet down.',
#  'Quiet down.',
#  'Quiet down.',
#  'Replace it.',
#  'Say cheese.',
#  'Say please.',
#  'Shadow him.',
#  'She is old.',
#  'Shove over.',
#  'Sing along.',
#  'Smell this.',
#  'Start here.',
#  'Start over.',
#  'Stay alert.',
#  'Stay awake.',
#  'Stay close.',
#  'Stay quiet.',
#  'Stay sharp.',
#  'Stay sharp.',
#  'Stay sharp.',
#  'Stay sharp.',
#  'Stay still.',
#  'Stay there.',
#  'Step aside.',
#  'Stop lying.',
#  'Stop there.',
#  'Study hard.',
#  'Take cover!',
#  'Take these.',
#  'Taste this.',
#  'That a boy!',
#  'That hurts.',
#  'That works.',
#  "That's all.",
#  "That's wet.",
#  'They agree.',
#  'They cheat.',
#  'They stood.',
#  'They tried.',
#  'They voted.',
#  'This works.',
#  "This'll do.",
#  'Time flies.',
#  'Tom agreed.',
#  'Tom agrees.',
#  'Tom burped.',
#  'Tom called.',
#  'Tom cheats.',
#  'Tom danced.',
#  'Tom dances.',
#  'Tom drinks.',
#  'Tom drives.',
#  'Tom failed.',
#  'Tom forgot.',
#  'Tom fought.',
#  'Tom gasped.',
#  'Tom goofed.',
#  'Tom helped.',
#  'Tom is shy.',
#  'Tom jumped.',
#  'Tom looked.',
#  'Tom moaned.',
#  'Tom obeyed.',
#  'Tom paused.',
#  'Tom phoned.',
#  'Tom prayed.',
#  'Tom sighed.',
#  'Tom smiled.',
#  'Tom snores.',
#  'Tom stayed.',
#  'Tom talked.',
#  'Tom waited.',
#  'Tom walked.',
#  'Tom winked.',
#  'Tom worked.',
#  'Tom yawned.',
#  'Tom yelled.',
#  "Tom'll pay.",
#  "Tom's deaf.",
#  "Tom's glad.",
#  "Tom's sick.",
#  'Tough luck!',
#  'Tough luck!',
#  'Tough luck!',
#  'Tough luck!',
#  'Tough luck!',
#  'Tough luck!',
#  'Try harder.',
#  'Try harder.',
#  'Try harder.',
#  'Turn right.',
#  'Watch this.',
#  'We are men.',
#  'We can try.',
#  'We must go.',
#  "We're boys.",
#  "We're home.",
#  "We're safe.",
#  'What is it?',
#  'Who did it?',
#  'Who phoned?',
#  'Who phoned?',
#  'Who saw me?',
#  'Who stayed?',
#  "Who's sick?",
#  'Why bother?',
#  'Why bother?',
#  'Wood burns.',
#  'You called?',
#  'You decide.',
#  'You missed.',
#  "You're bad.",
#  "You're big.",
#  "You're fun.",
#  "You're mad.",
#  "You're odd.",
#  "You're old.",
#  "You're sad.",
#  "You're shy.",
#  "You've won!",
#  "You've won!",
#  "You've won!",
#  "You've won!",
#  'All is well.',
#  'Am I hungry!',
#  'Anyone home?',
#  'Anyone hurt?',
#  'Are we lost?',
#  'Are we safe?',
#  'Are you new?',
#  'Ask anybody.',
#  'Ask anybody.',
#  'Be creative.',
#  'Be discreet.',
#  'Be friendly.',
#  'Be friendly.',
#  'Be friendly.',
#  'Be friendly.',
#  'Be friendly.',
#  'Be friendly.',
#  'Be merciful.',
#  'Be merciful.',
#  'Be merciful.',
#  'Be merciful.',
#  'Be prepared.',
#  'Be prepared.',
#  'Be prepared.',
#  'Be prepared.',
#  'Be prepared.',
#  'Be prepared.',
#  'Be punctual.',
#  'Be punctual.',
#  'Be ruthless.',
#  'Be ruthless.',
#  'Be ruthless.',
#  'Be sensible.',
#  'Be specific.',
#  'Be specific.',
#  'Be vigilant.',
#  'Can we come?',
#  'Can we help?',
#  'Can we stop?',
#  'Can you try?',
#  'Clean it up.',
#  'Comfort Tom.',
#  'Contact Tom.',
#  'Cover it up.',
#  'Did Tom cry?',
#  'Did Tom die?',
#  'Did Tom eat?',
#  'Do you mind?',
#  'Do you mind?',
#  'Do you mind?',
#  'Do you mind?',
#  'Do you mind?',
#  "Don't laugh.",
#  'Finish this.',
#  'Flip a coin.',
#  'Forgive Tom.',
#  'Get serious.',
#  'Go have fun.',
#  'Go help Tom.',
#  'Go with Tom.',
#  'He can come.',
#  'He can read.',
#  'He can swim.',
#  'He has come!',
#  'He is alone.',
#  'He is eight.',
#  'He is nasty.',
#  'He stood up.',
#  'He was busy.',
#  "He's my age.",
#  "He's strong.",
#  'Hello again.',
#  'Here I come.',
#  'Here we are!',
#  'How are you?',
#  ...]

# %%
pol_word
# Out:
# ['Idź.',
#  'Cześć.',
#  'Uciekaj!',
#  'Biegnij.',
#  'Uciekaj.',
#  'Kto?',
#  'O, dziamdzia zaprzała jej szadź!',
#  'Łał!',
#  'Pali się!',
#  'Strzelaj!',
#  'Ognia!',
#  'Pomocy!',
#  'Skacz!',
#  'Skok.',
#  'Stój!',
#  'Zatrzymaj się!',
#  'Czekaj!',
#  'Zaczekaj!',
#  'Poczekaj!',
#  'Czekajcie!',
#  'Poczekajcie!',
#  'Zaczekajcie!',
#  'Niech pan zaczeka!',
#  'Niech pani zaczeka!',
#  'Czekajcie.',
#  'Zaczekaj.',
#  'Czekaj.',
#  'Poczekaj.',
#  'Poczekajcie.',
#  'Zaczekajcie.',
#  'Zaczynaj.',
#  'Zaczynajcie.',
#  'Zrób to.',
#  'Cześć.',
#  'Pośpiesz się!',
#  'Rozumiem.',
#  'Widzę.',
#  'Próbuje.',
#  'Wygrałem!',
#  'O nie!',
#  'Wyluzuj.',
#  'Strzelaj!',
#  'Ognia!',
#  'Uśmiech.',
#  'Atak!',
#  'Na zdrowie!',
#  'Twoje zdrowie!',
#  'Zjedz to.',
#  'Stój!',
#  'Nie ruszaj się!',
#  'Wstawaj.',
#  'Idź już.',
#  'Rozumiesz?',
#  'Kapujesz?',
#  'On pobiegł.',
#  'Wskakuj.',
#  'Przytul mnie.',
#  'Przewróciłam się.',
#  'Wiem.',
#  'Wyjechałam.',
#  'Odszedłem.',
#  'Wyjechałam',
#  'Wyszłam.',
#  'Odeszłam.',
#  'Wyszedłem.',
#  'Przegrałem.',
#  'Wychodzę.',
#  'Ze mną wszystko w porządku.',
#  'Słuchaj.',
#  'Nie mam mowy!',
#  'Naprawdę?',
#  'Dziękuję!',
#  'Dzięki.',
#  'Próbujemy.',
#  'Dlaczego ja?',
#  'Spytaj Toma.',
#  'Zapytaj Toma.',
#  'Niesamowity!',
#  'Bądź spokojny.',
#  'Być luzakiem.',
#  'Bądź uczciwy.',
#  'Bądź miły.',
#  'Bądź miły.',
#  'Spadaj.',
#  'Zadzwoń do mnie.',
#  'Zadzwoń do nas.',
#  'Proszę wejść.',
#  'Wejdź.',
#  'Wchodź.',
#  'Wejdźcie.',
#  'Niech pan wejdzie.',
#  'Niech pani wejdzie.',
#  'Niech państwo wejdą.',
#  'Proszę wchodzić.',
#  'Zapraszam do środka.',
#  'Śmiało!',
#  'Dalej!',
#  'No chodź.',
#  'Rzuć to!',
#  'Zabierz Toma.',
#  'Przyprowadź Toma.',
#  'Wynoś się!',
#  'Wynoś się!',
#  'Wynocha.',
#  'Idź stąd.',
#  'Idź sobie.',
#  'Odejdź.',
#  'Idź do domu.',
#  'Do widzenia!',
#  'Wytrzymać.',
#  'Przyszedł.',
#  'Poszedł sobie.',
#  'On biega.',
#  'Pomóż mi!',
#  'Pomóż mi.',
#  'Cześć, Tom.',
#  'Uderz Toma.',
#  'Trzymaj się!',
#  'Czekaj.',
#  'Proszę poczekać.',
#  'Chwileczkę.',
#  'Przytul Toma.',
#  'Zgadzam się.',
#  'Ukłoniłem się.',
#  'Palę.',
#  'Śmierdzę.',
#  'Próbowałem.',
#  'Ja pójdę.',
#  'Jestem Tom.',
#  'Jestem stary.',
#  'Jestem smutny.',
#  'Jestem nieśmiały.',
#  'Jestem wstydliwy.',
#  'To ja.',
#  'Oto ja.',
#  'Dołącz do nas.',
#  'Przyłącz się do nas.',
#  'Zatrzymaj to.',
#  'Pocałuj mnie.',
#  'Ja także.',
#  'Ja też.',
#  'Otwierać.',
#  'Doskonale!',
#  'Odpuść sobie!',
#  'Na razie!',
#  'Do zobaczenia!',
#  'Pokaż mi.',
#  'Zamknij się!',
#  'Przestań.',
#  'Weź to.',
#  'Powiedz mi.',
#  'Tom zjadł.',
#  'Tom biegał.',
#  'Zaczekaj.',
#  'Czekaj.',
#  'Obudź się!',
#  'Obudź się.',
#  'Przegraliśmy.',
#  'Witamy.',
#  'Witam.',
#  'Kto jadł?',
#  'Kto biegł?',
#  'Kto wygrał?',
#  'Uruchomić.',
#  'Wygrałeś.',
#  'Odsuń się!',
#  'Odsuń się.',
#  'Bądź cicho.',
#  'Cicho.',
#  'Siedź cicho.',
#  'Milcz.',
#  'Bądź spokojna.',
#  'Spadaj.',
#  'Odczep się.',
#  'Odwal się.',
#  'Zjeżdżaj.',
#  'Zadzwoń Tom.',
#  'Głowa do góry!',
#  'Uśmiechnij się.',
#  'Rozchmurz się.',
#  'Głowa do góry.',
#  'Rozchmurzcie się.',
#  'Uspokój się!',
#  'Skuć go.',
#  'Jedź dalej.',
#  'Znajdź Toma.',
#  'Napraw to.',
#  'Na ziemię!',
#  'Schodzić.',
#  'Idź precz!',
#  'Spadaj.',
#  'Ogarnij się!',
#  'Obudź się.',
#  'Zejdź na ziemię.',
#  'Bądź realistą.',
#  'No dalej!',
#  'Śmiało.',
#  'No dalej.',
#  'Dalej.',
#  'Dobra robota!',
#  'Złap Toma.',
#  'Złap go.',
#  'Miłej zabawy.',
#  'Próbował.',
#  'On się stara.',
#  'On próbuje.',
#  'Pomóż Tom.',
#  'Jak uroczo!',
#  'Jak głęboko?',
#  'Jak miło!',
#  'Pośpiesz się!',
#  'Zgodziłem się.',
#  'Przytaknęłam.',
#  'Wyraziłem zgodę.',
#  'Ja to zrobiłem.',
#  'Zawiodłem.',
#  'Nawaliłem.',
#  'Poniosłem klęskę.',
#  'Nie udało mi się.',
#  'Zawaliłem sprawę.',
#  'Poniosłem porażkę.',
#  'Poległam.',
#  'Zapomniałem.',
#  'Rozumiem.',
#  'Złapałem!',
#  'Dzwoniłem.',
#  'Odchodzę.',
#  'Składam wypowiedzenie.',
#  'Uśmiechnąłem się.',
#  'Zostałem.',
#  'Ja zapłacę.',
#  'Spróbuję.',
#  'Jestem zajęty.',
#  'Zarobiony jestem.',
#  'Jestem spokojny.',
#  'Mam dość.',
#  'Jestem sprawiedliwy.',
#  'Jestem wolny!',
#  'Jestem pełny.',
#  'Cieszę się.',
#  'Jestem tutaj.',
#  'Jestem w domu.',
#  'Jestem ranny.',
#  'Jestem spóźniony.',
#  'Zgubiłem się.',
#  'Jestem bezradny.',
#  'Jestem zdezorientowany.',
#  'Jestem wredny.',
#  'Jestem następny.',
#  'Jestem biedny.',
#  'Jestem bogaty.',
#  'Jestem bezpieczny.',
#  'Jestem chory.',
#  'Jestem pewny.',
#  'Jest mi ciepło.',
#  'Jestem słaby.',
#  'Jestem mądry.',
#  'Wygrałem.',
#  'To działa.',
#  'Jest gorąco.',
#  'To jest nowe.',
#  'Jest czerwone.',
#  'Jest czerwony.',
#  'Jest czerwona.',
#  'Nie wchodzić!',
#  'Wstęp wzbroniony.',
#  'Pocałuj Toma.',
#  'Zostaw to.',
#  'Zostaw mnie.',
#  'Zostaw nas.',
#  'Chodźmy!',
#  'Uważaj!',
#  'Wyjdź za mnie.',
#  'Mogę iść?',
#  'Uratuj Toma.',
#  'Przyszła.',
#  'Biegnie.',
#  'Usiądź!',
#  'Siadaj!',
#  'Usiądź.',
#  'Usiądź tutaj.',
#  'Mów głośniej!',
#  'Przygotuj się.',
#  'Wstawaj!',
#  'Zostań na miejscu.',
#  'Zatrzymaj się Tom.',
#  'Zabierz Toma.',
#  'Powiedz Tomowi.',
#  'Niesamowity.',
#  'Wygrali.',
#  'Tom przyszedł.',
#  'Tom umarł.',
#  'Tom upadł.',
#  'Tom wiedział.',
#  'Tom wyszedł.',
#  'Tom skłamał.',
#  'Tom kłamie.',
#  'Tom przegrał.',
#  'Tom zapłacił.',
#  'Tom wyszedł.',
#  'Tom płynął.',
#  'Dotknij tego.',
#  'Zaufaj mi.',
#  'Staraj się mocno.',
#  'Spróbuj trochę.',
#  'Spróbuj tego.',
#  'Użyj tego.',
#  'Ostrzeż Toma.',
#  'Patrz na mnie.',
#  'Patrzą na nas.',
#  'Zgadzamy się.',
#  'Po co?',
#  'Ale zabawa!',
#  'Kto umarł?',
#  'Kto zmarł?',
#  'Kto upadł?',
#  'Kto wyszedł?',
#  'Kim on jest?',
#  'Napisz do mnie.',
#  'Proszę przodem.',
#  'Cel. Ogień!',
#  'Usiądź.',
#  'Ptaki latają.',
#  'Uspokój się!',
#  'Opanuj się!',
#  'Uspokój się.',
#  'Mogę już jeść?',
#  'Złap Tom.',
#  'Złap go.',
#  'Uspokój się.',
#  'Wyluzuj.',
#  'Wróć.',
#  'Chodź tu.',
#  'Chodź do domu.',
#  'Wpadnij do mnie!',
#  'Przyjść.',
#  'Już wkrótce.',
#  'Uspokój się.',
#  'Wygrałem?',
#  'Zrób to teraz.',
#  'Psy szczekają.',
#  'Nie płacz.',
#  'Nie umieraj!',
#  'Nie kłam.',
#  'Proszę?',
#  'Słucham?',
#  'Przepraszam?',
#  'Fantastyczny!',
#  'Poczuj to.',
#  'Chodź za mną.',
#  'Dołącz do nas.',
#  'Zapomnij o tym!',
#  'Zapomnij!',
#  'Nie ma mowy!',
#  'Zapomnij o tym!',
#  'Nie ma o czym mówić.',
#  'Zapomnij!',
#  'Przygotuj się.',
#  'Idź do środka.',
#  'Weź to.',
#  'Weź tamto.',
#  'Weź to.',
#  'Ręce precz.',
#  'Częstuj się.',
#  'Napij się.',
#  'On jest chory.',
#  'Jest stary.',
#  'Ogolił się.',
#  'Uśmiechnął się.',
#  'Jest DJ-em.',
#  'On jest zajęty.',
#  'Jest bogaty.',
#  'Wstrzymać ogień.',
#  'Potrzymaj.',
#  'Udobruchaj Toma.',
#  'Jestem dobry!',
#  'Jestem chory.',
#  'Jestem pewny.',
#  'Jestem pewna.',
#  'Jestem wysoki.',
#  'U mnie wszystko w porządku.',
#  'Klaskałem.',
#  'Skrzywiłem się.',
#  'Wzdrygnęłam się.',
#  'Zemdlałem.',
#  'Zemdlałam.',
#  'Rozumiem, o co ci chodzi.',
#  'Uderzyłem Toma.',
#  'Spieszyłem się.',
#  'Śmiałem się.',
#  'Udało mi się.',
#  'Muszę iść.',
#  'Zauważyłem.',
#  'Zauważyłam.',
#  'Powiedziałem nie.',
#  'Widzę Toma.',
#  'Krzyknąłem.',
#  'Zatrzymałem się.',
#  'Przewróciłem się.',
#  'Potknęłam się.',
#  'Potknąłem się.',
#  'Wyjechałbym.',
#  'Zadzwonię.',
#  'Ugotuję.',
#  'Przeżyję.',
#  'Odpuszczę.',
#  'Będę śpiewać.',
#  'Zostanę.',
#  'Przestanę.',
#  'Powiem.',
#  'Poczekam.',
#  'Będę chodzić.',
#  'Jestem mężczyzną.',
#  'Jestem uzbrojony.',
#  'Jestem niewidomy.',
#  'Nudzi mi się.',
#  'Nudzę się.',
#  'Jestem odważny.',
#  'Jestem spłukany.',
#  'Jestem czysty.',
#  'Jestem wyleczony.',
#  'Jestem pijany.',
#  'Jestem pierwszy.',
#  'Idę.',
#  'Jestem szczęśliwy.',
#  'Jestem szczęśliwa.',
#  'Jestem cichy.',
#  'Jestem gotowy.',
#  'Mam rację.',
#  'Jestem mądry.',
#  'Jestem trzeźwy.',
#  'Przykro mi.',
#  'Utknąłem.',
#  'Jestem zmęczony.',
#  'Jestem twardy.',
#  'Jestem młody.',
#  'Jestem twój.',
#  'Straciłem.',
#  'Nie zwracaj na to uwagi.',
#  'Czy jest gorąco?',
#  'Czy to jest gorące?',
#  'Nie powiodło się.',
#  'Nie udało się.',
#  'Padał śnieg.',
#  'Śmierdzi.',
#  'To śmierdzi.',
#  'Udało się.',
#  'Zadziałało.',
#  'Jest trzecia trzydzieści.',
#  'To jest telewizja.',
#  'To łatwe.',
#  'To jest trudne.',
#  'Jest późno.',
#  'To praca.',
#  'Nie zbliżać się.',
#  'Zatrzymać się.',
#  'Zachowaj spokój.',
#  'Uspokój się.',
#  'Nie wstawaj.',
#  'Zatrzymać to.',
#  'Zatrzymać je.',
#  'Trzymaj to.',
#  'Utrzymuj ciepło.',
#  'Zostaw Toma.',
#  'Idź już.',
#  'Wyjdź w tej chwili!',
#  'Wyjdź natychmiast!',
#  'Odejdźcie!',
#  'Niech tak będzie.',
#  'Zapytajmy.',
#  'Zjedzmy.',
#  'Spróbujmy.',
#  'Leż spokojnie.',
#  'Słuchaj.',
#  'Posłuchajcie.',
#  'Proszę posłuchać.',
#  'Niech pani posłucha.',
#  'Posłuchaj.',
#  'Odwrócić wzrok.',
#  'Spójrz wstecz!',
#  'Spójrz wstecz.',
#  'Popatrz tutaj.',
#  'Poluzowałeś to.',
#  'Wrzuć na luz.',
#  'Przesuń się.',
#  'Niezły strzał!',
#  'Oczywiście!',
#  'Oczywiście.',
#  'Och proszę!',
#  'Ognia!',
#  'Strzelać!',
#  'Słucham?',
#  'Cisza!',
#  'Morda w kubeł!',
#  'Przestańcie gadać!',
#  'Mordy w kubeł!',
#  'Zamknąć japy!',
#  'Przymknij się!',
#  'Zamknąć się!',
#  'Pozamykać się!',
#  'Pozamykać gęby!',
#  'Proszę iść.',
#  'Proszę, idź.',
#  'Niech pan idzie.',
#  'Przeczytaj to.',
#  'Przeczytajcie to.',
#  'Powiedz „aaa”.',
#  'Powiedz cześć.',
#  'Przywitaj się.',
#  'Patrz poniżej.',
#  'Pojmać go!',
#  'Naprawdę?',
#  'Poważnie?',
#  'Serio?',
#  'Ona płakała.',
#  'Próbowała.',
#  'Ona idzie.',
#  'Podpisz to.',
#  'Usiedzieć.',
#  'Usiądź tam.',
#  'Usiądźcie tam.',
#  'Uspokój się!',
#  'Nie tak szybko!',
#  'Zwolnij!',
#  'Wolniej!',
#  'Proszę zwolnić!',
#  'Przystopuj trochę!',
#  'Nie śpiesz się tak!',
#  'Zacząć teraz.',
#  'Trzymaj się z daleka.',
#  'Nie podchodź.',
#  'Spokojnie.',
#  'Zachowaj spokój.',
#  'Nie ruszaj się!',
#  'Nie wstawaj!',
#  'Leż!',
#  'Nie podnoś się!',
#  'Zostań tam!',
#  'Nie wychylaj się!',
#  'Nie wstawaj.',
#  'Zostań tutaj.',
#  'Zostań w domu.',
#  'Krok do tyłu.',
#  'Zatrzymaj się tutaj.',
#  'Przestań.',
#  'Zatrzymaj ich.',
#  'Trzymaj się!',
#  'Trzymaj się!',
#  'Przejąć.',
#  'Weź to.',
#  'Dziękuję!',
#  'Dziękuję.',
#  'To jest to.',
#  'To co?',
#  'Poczuli.',
#  'Wyszli.',
#  'Kłamali.',
#  'Zgubili.',
#  'Płynęli.',
#  'Tom troszczył się.',
#  'Tom troszczy się.',
#  'Tom płakał.',
#  'Tom drzemał.',
#  'Tom przyjechał.',
#  'Tom robi na drutach.',
#  'Tom dzierga.',
#  'Tom wie.',
#  'Tom się przeprowadził.',
#  'Tom kołysał się.',
#  'Tom mówił.',
#  'Tom stał.',
#  'Tom pływa.',
#  'Tom próbował.',
#  'Tom próbuje.',
#  'Tom głosował.',
#  'Tom chodzi.',
#  'Tom pomachał.',
#  'Tom pracuje.',
#  'Tom jest nieśmiały.',
#  'Zaufaj Tom.',
#  'Spróbuj jeszcze raz.',
#  'Skręć w lewo.',
#  'Otwórz to.',
#  'Zaczekaj tutaj.',
#  'Oglądaj Tom.',
#  'Uważaj!',
#  'Udało się.',
#  'Zrobiliśmy to.',
#  'Zapomnieliśmy.',
#  'Zapomniałyśmy.',
#  'Mówiliśmy.',
#  'Czekaliśmy.',
#  'Zobaczymy.',
#  'Jesteśmy smutni.',
#  'Dobra robota!',
#  'Jak leci?',
#  'Co jest?',
#  'Kogo to obchodzi?',
#  'Kto wie?',
#  'Kto zna?',
#  'Kto mówił?',
#  'Kto zabrał głos?',
#  'Kto się wypowiadał?',
#  'Kto zabierał głos?',
#  'Kto stał?',
#  'Kim ona jest?',
#  'Cudownie!',
#  'Cudowny',
#  'Cudowna',
#  'Świetnie!',
#  'Pisz Tom.',
#  'Ty głupcze!',
#  'Ty zaczynasz.',
#  'Próbowałeś.',
#  'Jesteś w porządku.',
#  'Wszyscy na pokład!',
#  'Czy nie mam racji?',
#  'Odpowiedz Tom.',
#  'Czy wszystko w porządku?',
#  'Wszystko z tobą dobrze?',
#  'Czy wszystko u ciebie OK?',
#  'Spytaj kogoś.',
#  'Poproś kogoś.',
#  'Popytaj.',
#  'Bądź ostrożny.',
#  'Bądź ostrożny.',
#  'Uważaj.',
#  'Bądź zadowolony.',
#  'Ciesz się.',
#  'Niech cię to zadowoli.',
#  'Będę na czas.',
#  'Bądź cierpliwy.',
#  'Bądź cierpliwa.',
#  'Cierpliwości.',
#  'Bądź poważny.',
#  'Mów poważnie.',
#  'Ptaki śpiewają.',
#  'Na zdrowie!',
#  'Zdrówko!',
#  'Do dna!',
#  'Przenieś to.',
#  'Sprawdź to.',
#  'Wybierz jeden.',
#  'Proszę wybrać jeden.',
#  'Zbliżać się.',
#  'Zdecydowanie!',
#  'Zniszcz to.',
#  'Nie ruszaj się.',
#  'Jedz powoli.',
#  'Zbadaj to.',
#  'Spójrz prawdzie w oczy!',
#  'Licz się z faktami!',
#  'Staw czoła faktom!',
#  'Napełnij to.',
#  'Ogień parzy.',
#  'Śledź Toma.',
#  'Śledź go.',
#  'Zapomnij Tom.',
#  'Zapomnij o nim.',
#  'Przebacz mi.',
#  'Bóg istnieje.',
#  'Dobrej nocy.',
#  'Dał za wygraną.',
#  'Jest DJ-em.',
#  'On tu jest!',
#  'On jest miły.',
#  'On jest biedny.',
#  'On jest chory.',
#  'On jest mądry.',
#  'Nie ruszaj się.',
#  'Leż spokojnie.',
#  'Nie wierć się.',
#  'Stój spokojnie.',
#  'Stój nieruchomo.',
#  'Siedź spokojnie.',
#  'Przestań się wiercić.',
#  'Co za absurd!',
#  'Ale absurd!',
#  'Ależ absurdalne!',
#  'Ale niedorzeczne!',
#  'Ale sprytnie!',
#  'Bardzo sprytnie!',
#  'Jak sprytnie!',
#  'Ależ sprytnie!',
#  'Jak słodko!',
#  'Co za tragedia!',
#  'Wróć szybko.',
#  'Wracaj szybko.',
#  'Wróćcie szybko.',
#  'Spiesz się do domu.',
#  'Jestem chłopakiem.',
#  'Jestem mężczyzną.',
#  'Jestem człowiekiem.',
#  'Jestem szczęśliwy.',
#  'Jestem gotowy.',
#  'Jestem niski.',
#  'Jestem niska.',
#  'Jestem sprytny.',
#  "Pobiłem Tom'a.",
#  'Odwołałem.',
#  'Nie zgadzam się.',
#  'Wątpię w to.',
#  'Zjem tutaj.',
#  'Jem mięso.',
#  'Chyba tak.',
#  'Nienawidzę Toma.',
#  'Nienawidzę cię.',
#  'Mam cię w dupie.',
#  'Znam Toma.',
#  'Znam ją.',
#  'Znam go.',
#  'Uwielbiam sztukę.',
#  'Lubię go.',
#  'Lubię herbatę.',
#  'Lubię cię.',
#  'Słuchałem.',
#  'Kocham go.',
#  'Kocham cię.',
#  'Tęsknię za Tobą.',
#  'Tęsknię za tobą.',
#  'Potrzebuję powietrza.',
#  'Potrzebuję cię.',
#  'Przeżyłem.',
#  'Chyba tak.',
#  'Tak mi się wydaje.',
#  'Chcę ciebie.',
#  'Byłem chory.',
#  'Sprawdzę.',
#  'Ja prowadzę.',
#  'Odejdę.',
#  'Będę strzelać.',
#  'Postoję.',
#  'Zacznę.',
#  'Mam teraz trzydzieści lat.',
#  'Jestem bohaterem.',
#  'Jestem anemikiem.',
#  'Jestem wyczerpany.',
#  'Już idę.',
#  'Jestem bezpośrednia.',
#  'Jestem bezpośredni.',
#  'Jem.',
#  'Jestem głodny.',
#  'Jestem w łóżku.',
#  'Jestem dojrzały.',
#  'Ja płacę.',
#  'Jestem wykończony!',
#  'Boję się.',
#  'Jestem bezwzględny.',
#  'Jestem silny.',
#  'Ignoruj Toma.',
#  'Ignoruj go.',
#  'Zignoruj go.',
#  'To jest niebieskie?',
#  'Czy to miłość?',
#  'Jest 7:30.',
#  'Jest siódma trzydzieści.',
#  'Jest wpół do ósmej.',
#  'Jest trzydzieści po siódmej.',
#  'Jest siódma czterdzieści pięć.',
#  'Jest ciepło.',
#  'To ma znaczenie.',
#  'To było smutne.',
#  'Jest wcześnie.',
#  'Tak jest bezpieczniej.',
#  'To jest bezpieczniejsze.',
#  'Jest wietrznie.',
#  'Jezus zapłakał.',
#  'Nie poddawaj się.',
#  'Zrób notatki.',
#  'Bądź cicho!',
#  'Bądź cicho.',
#  'Keep still.',
#  'Opuścić miasto.',
#  'Pozwól mi zapłacić.',
#  'Porozmawiajmy.',
#  'Pracujmy.',
#  'Rozjaśnić.',
#  'Spójrz ponownie.',
#  'Patrz przed siebie.',
#  'Spójrz alarm.',
#  'Wyglądać żywo.',
#  'Spójrz tam.',
#  'Popatrz tam.',
#  'Miłość boli.',
#  'Miłość trwa.',
#  'Mama płakała.',
#  'Nieważne!',
#  'Już nieważne!',
#  'Nie szkodzi!',
#  'Nie przejmuj się!',
#  'Nic nie szkodzi!',
#  'Mniejsza o to!',
#  'Bez komentarza.',
#  'Nie ma problemu!',
#  'Żaden problem!',
#  'Nie ma sprawy!',
#  'W porządku!',
#  'Nie ma problemu.',
#  'Nie ma sprawy.',
#  'Jeszcze raz.',
#  'Proszę usiąść.',
#  'Uspokój się.',
#  'Bądź cicho.',
#  'Uspokójcie się.',
#  'Bądźcie cicho.',
#  'Wymień to.',
#  'Powiedz ser.',
#  'Proszę powiedz.',
#  'Śledź go.',
#  'Ona jest stara.',
#  'Wpakować się.',
#  'Wspólnie śpiewać.',
#  'Powąchaj to.',
#  'Zacznij tutaj.',
#  'Zacząć od nowa.',
#  'Bądź czujny.',
#  'Nie zasypiaj.',
#  'Trzymaj się blisko.',
#  'Zamknij się.',
#  'Bądź czujny.',
#  'Bądź ostrożny.',
#  'Bądźcie czujni.',
#  'Miej się na baczności.',
#  'Nie ruszaj się.',
#  'Zostań tam.',
#  'Odsuń się.',
#  'Przestań kłamać.',
#  'Zatrzymaj się.',
#  'Ucz się pilnie.',
#  'Kryć się!',
#  'Weź to.',
#  'Posmakuj to.',
#  'To chłopiec!',
#  'To boli.',
#  'To działa.',
#  'To wszystko.',
#  'To jest mokre.',
#  'Zgadzają się.',
#  'Oszukują.',
#  'Oni stali.',
#  'Próbowali.',
#  'Głosowali.',
#  'To działa.',
#  'Może być.',
#  'Czas leci.',
#  'Tom się zgodził.',
#  'Tom się zgadza.',
#  'Tom beknął.',
#  'Tom dzwonił.',
#  'Tom oszukuje.',
#  'Tom tańczył.',
#  'Tom tańczy.',
#  'Tom pije.',
#  'Tom prowadzi.',
#  'Tom zawiódł.',
#  'Tom zapomniał.',
#  'Tom walczył.',
#  'Tom sapał.',
#  'Tom popełnił gafę.',
#  'Tom pomógł.',
#  'Tom jest nieśmiały.',
#  'Tom skoczył.',
#  'Tom spojrzał.',
#  'Tom jęknął.',
#  'Tom posłuchał.',
#  'Tom przerwał.',
#  'Tom zadzwonił.',
#  'Tom modlił się.',
#  'Tom westchnął.',
#  'Tom się uśmiechnął.',
#  'Tom chrapie.',
#  'Tom został.',
#  'Tom mówił.',
#  'Tom czekał.',
#  'Tom szedł.',
#  'Tom mrugnął.',
#  'Tom pracował.',
#  'Tom ziewnął.',
#  'Tom krzyknął.',
#  'Tom zapłaci.',
#  'Tom jest głuchy.',
#  'Tom jest zadowolony.',
#  'Tom jest chory.',
#  'A to pech!',
#  'Trudno!',
#  'Masz pecha!',
#  'Mówi się trudno!',
#  'Co za pech!',
#  'Pech!',
#  'Bardziej się staraj.',
#  'Próbuj dalej.',
#  'Postaraj się bardziej.',
#  'Skręć w prawo.',
#  'Patrz na to.',
#  'Jesteśmy mężczyznami.',
#  'Możemy spróbować.',
#  'Musimy iść.',
#  'Jesteśmy chłopakami.',
#  'Jesteśmy w domu.',
#  'Jesteśmy bezpieczni.',
#  'Co to jest?',
#  'Kto to zrobił?',
#  'Kto zadzwonił?',
#  'Kto dzwonił?',
#  'Kto mnie widział?',
#  'Kto został?',
#  'Kto jest chory?',
#  'Po co się trudzić?',
#  'Po co zawracać sobie głowę?',
#  'Drewno się pali.',
#  'Zadzwoniłeś?',
#  'Ty zdecyduj.',
#  'Nie trafiłeś.',
#  'Jesteś zły.',
#  'Jesteś wielki.',
#  'Jesteś zabawy.',
#  'Jesteś szalony.',
#  'Jesteś dziwny.',
#  'Jesteś stary.',
#  'Jesteś smutny.',
#  'Jesteś nieśmiały.',
#  'Wygrałeś!',
#  'Wygrałaś!',
#  'Wygraliście!',
#  'Wygrałyście!',
#  'Wszystko jest dobre.',
#  'Jestem głodny!',
#  'Jest ktoś w domu?',
#  'Są ranni?',
#  'Zgubiliśmy się?',
#  'Jesteśmy bezpieczni?',
#  'Jesteś nowy?',
#  'Zapytaj kogokolwiek.',
#  'Spytaj kogokolwiek.',
#  'Bądź kreatywny.',
#  'Bądź dyskretny.',
#  'Bądź miły.',
#  'Bądź przyjazny.',
#  'Bądź przyjacielski.',
#  'Bądźcie mili.',
#  'Bądźcie dla siebie mili.',
#  'Bądź miła.',
#  'Okaż miłosierdzie.',
#  'Bądź miłosierny.',
#  'Bądź litościwy.',
#  'Miej litość.',
#  'Przygotuj się.',
#  'Bądź gotowy.',
#  'Bądź gotów.',
#  'Bądź gotowa.',
#  'Bądź przygotowany.',
#  'Przygotujcie się.',
#  'Nie spóźnij się.',
#  'Bądź punktualny.',
#  'Bądź bezwzględny.',
#  'Bądź bezlitosny.',
#  'Nie miej litości.',
#  'Bądź rozsądny.',
#  'Bądź bardziej dokładny.',
#  'Bądź dokładny.',
#  'Bądź czujny.',
#  'Możemy przyjść?',
#  'Czy możemy ci pomóc?',
#  'Możemy zakończyć?',
#  'Możesz spróbować?',
#  'Posprzątaj to.',
#  'Pociesz Toma.',
#  'Kontakt z Tomem.',
#  'Przykryj to.',
#  'Czy Tom płakał?',
#  'Czy Tom umarł?',
#  'Czy Tom zjadł?',
#  'Masz coś przeciwko?',
#  'Nie masz nic przeciwko?',
#  'Nie przeszkadza ci to?',
#  'Czy ci to przeszkadza?',
#  'Przejmujesz się tym?',
#  'Nie śmiej się.',
#  'Skończ to.',
#  'Rzuć monetą.',
#  'Wybacz Tom.',
#  'Bądź poważny.',
#  'Idź się bawić.',
#  'Idź pomóc Tomowi.',
#  'Idź z Tomem.',
#  'Może przyjść.',
#  'On umie czytać.',
#  'On umie pływać.',
#  'On przyszedł!',
#  'On jest sam.',
#  'On ma osiem lat.',
#  'On jest okropny.',
#  'Wstał.',
#  'Był zajęty.',
#  'On jest w tym samym wieku co ja.',
#  'On jest silny.',
#  'Witam ponownie.',
#  'Nadchodzę.',
#  'Jesteśmy na miejscu!',
#  'Jak się masz?',
#  ...]

# %%
language_data = pd.DataFrame(columns=['English','Polish'])
language_data['English'] = english_word
language_data['Polish'] = pol_word

# %%
language_data
# Out:
#                                                  English  \
# 0                                                    Go.
# 1                                                    Hi.
# 2                                                   Run!
# 3                                                   Run.
# 4                                                   Run.
# ...                                                  ...
# 39995  Tom would've done that correctly the first tim...
# 39996  Tom, Mary, John and Alice were sitting around ...
# 39997  We consider it the citizens' legitimate right ...
# 39998  We just want to ask him a few questions about ...
# 39999  We learn from experience that men never learn ...
#
#                                                   Polish
# 0                                                   Idź.
# 1                                                 Cześć.
# 2                                               Uciekaj!
# 3                                               Biegnij.
# 4                                               Uciekaj.
# ...                                                  ...
# 39995  Tom zrobiłby to poprawnie za pierwszym razem, ...
# 39996  Tom, Mary, John i Alice siedzieli dookoła stoł...
# 39997  Biblioteki publiczne uznajemy za podstawowe pr...
# 39998  Chcemy tylko zadać mu kilka pytań na temat teg...
# 39999  Doświadczenie uczy, że nie uczy ono ludzi nicz...
#
# [40000 rows x 2 columns]

# %%
language_data.to_csv('language_data.csv', index=False)

# %%
english_text = language_data['English'].values
polish_text = language_data['Polish'].values
len(english_text), len(polish_text)
# Out:
# (40000, 40000)

# %% [markdown]
# ## Data Cleaning

# %%
english_text = [x.lower() for x in english_text]
polish_text = [x.lower() for x in polish_text]

# %%
english_text = [re.sub("'",'',x) for x in english_text]
marathi_text = [re.sub("'",'',x) for x in polish_text]
